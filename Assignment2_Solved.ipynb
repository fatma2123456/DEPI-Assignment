# %% [markdown]
# # Assignment 2:  Unlocking Statistical Insights with Python
#
# In this assignment, you'll dive into the world of statistical analysis using Python.  We'll move beyond theoretical concepts and focus on practical application. You'll learn how to calculate key statistical measures and use them for real-world tasks like outlier detection.
#
# This assignment will guide you through:
#
# * **Revise the concepts and equations:**  You'll implement code from scratch to compute essential statistics like mean, median, mode, variance, standard deviation, range, and interquartile range (IQR).
# * **Calculating Basic Statistics:**  You'll implement code from scratch to compute essential statistics like mean, median, mode, variance, standard deviation, range, and interquartile range (IQR).
# * **Explore some liberaries**: Optionaly use powerful libraries like NumPy and SciPy.
#
#
# #### General Instructions
#
# Please adhere to the following guidelines:
#
# - **Code Clarity:** Your code should be well-formatted, easy to understand, and include meaningful variable names.
# - **Docstrings:**  Use docstrings to document your functions and explain their purpose, arguments, and return values.
# - **Testing:**  Use the same given data example of your code to demonstrate its functionality.
# - **NOTE:** Answer in the same notebook with the given examples.

# %% [markdown]
# ### **1.  Text Analyzer**
#
# * **Objective:**  Create a program that analyzes text for various characteristics.
# * **Requirements:**
#     * Ask the user to input a paragraph of text.
#     * Use loops to:
#         * Count the number of words in the text.
#         * Count the number of sentences in the text.
#         * Calculate the average word length.
#         * Find the most frequently used word in the text.
#         * (Optional) Identify the five most common words.
# * **Hint:** You'll need to use string manipulation techniques (like splitting the text into words and sentences) along with loop logic to track counts and comparisons.
#
# >**You can test the code using this paragraph:** "Python is a high-level, interpreted programming language. It's dynamically typed, meaning you don't have to explicitly declare the type of a variable. It's widely used for web development, data analysis, machine learning, and automation. Python is known for its readability and ease of use."

# %%
pragraph = input("Enter a paragraph of text: ")
pragraph_list=pragraph.split()
print(pragraph_list)
print(len(pragraph_list))
# Out:
# Enter a paragraph of text: Python is a high-level, interpreted programming language. It's dynamically typed, meaning you don't have to explicitly declare the type of a variable. It's widely used for web development, data analysis, machine learning, and automation. Python is known for its readability and ease of use
# ['Python', 'is', 'a', 'high-level,', 'interpreted', 'programming', 'language.', "It's", 'dynamically', 'typed,', 'meaning', 'you', "don't", 'have', 'to', 'explicitly', 'declare', 'the', 'type', 'of', 'a', 'variable.', "It's", 'widely', 'used', 'for', 'web', 'development,', 'data', 'analysis,', 'machine', 'learning,', 'and', 'automation.', 'Python', 'is', 'known', 'for', 'its', 'readability', 'and', 'ease', 'of', 'use']
# 44

# %%
pragraph_list_sentence=pragraph.split(".")
print(pragraph_list_sentence)
print(len(pragraph_list_sentence))
# Out:
# ['Python is a high-level, interpreted programming language', " It's dynamically typed, meaning you don't have to explicitly declare the type of a variable", " It's widely used for web development, data analysis, machine learning, and automation", ' Python is known for its readability and ease of use']
# 4

# %%
pragraph_avarage_length_words=pragraph.replace(",", "").replace(".", "")
pragraph_avarage_length_words=pragraph_avarage_length_words.split()
print(pragraph_avarage_length_words)
word=""
for i in pragraph_avarage_length_words:
    if len(i)>len(word):
        word=i
print(word)
# Out:
# ['Python', 'is', 'a', 'high-level', 'interpreted', 'programming', 'language', "It's", 'dynamically', 'typed', 'meaning', 'you', "don't", 'have', 'to', 'explicitly', 'declare', 'the', 'type', 'of', 'a', 'variable', "It's", 'widely', 'used', 'for', 'web', 'development', 'data', 'analysis', 'machine', 'learning', 'and', 'automation', 'Python', 'is', 'known', 'for', 'its', 'readability', 'and', 'ease', 'of', 'use']
# interpreted

# %%
avrage_lentgh_of_words=0
for i in pragraph_avarage_length_words:
    avrage_lentgh_of_words+=len(i)
print(avrage_lentgh_of_words/len(pragraph_avarage_length_words))
# Out:
# 5.409090909090909

# %%
count=1
for i in pragraph_avarage_length_words:
    if pragraph_avarage_length_words.count(i)>count:
        count=pragraph_avarage_length_words.count(i)
        print(i)
print(count)
# Out:
# Python
# 2

# %%
# Out:
# --- Text Analysis ---
# Word Count: 12
# Sentence Count: 4
# Average Word Length: 3.42
# Most Frequent Word: Hello.

# %% [markdown]
# ---
#
# ### **Q2- Basic Statistics Calculator**
#
# **Objective:** Create a Python program that calculates basic statistics (mean, median, mode, range, variance, and standard deviation) for a set of numbers entered by the user.
#
# **Requirements:**
# Complete each statistical calculation by following the TODO instructions below. It is mandatory to implement all calculations from scratch. Using libraries in combination with your own implementation is considered an added advantage.

# %%
# Initialize an empty list to store numbers
temperatures = [23, 25, 20, 23, -5, 21, 18, 19, 24, 21,19, 24, 0,
                20, 24, 55, 22, 50, 22, 20, 21, 22, 20, 25, 19,
                22, 26, 23, 21, 23, 17, 20, 18]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
total_sum=0
for i in temperatures:
    total_sum=total_sum+i
mean=total_sum/len(temperatures)
print(mean)
# Out:
# 21.87878787878788

# %%
print(sum(temperatures)/len(temperatures))
# Out:
# 21.87878787878788

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s_l=sorted(temperatures)
print(s_l)
# Middle For List
middle=len(s_l)//2
# If The Len For List Is Even
if len(s_l)%2==0:
    median=(s_l[middle]+s_l[middle-1])/2
else:
    median=s_l[middle]
print(median)
# Out:
# [-5, 0, 17, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 21, 21, 21, 21, 22, 22, 22, 22, 23, 23, 23, 23, 24, 24, 24, 25, 25, 26, 50, 55]
# 21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculate Mode
number_most_frequent = None
for i in temperatures:
    if temperatures.count(i) > temperatures.count(number_most_frequent):
        number_most_frequent = i
print(number_most_frequent)
# Out:
# 20

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=len(temperatures)
if n<=1:
  variance=0
else:
  for i in range(n):
    # Using Mean Sum all values by the number of values
    variance+=(temperatures[i]-mean)**2
  variance=variance/(n)
print(variance)
# Out:
# 101.26677240726826

# %%
import statistics
if len(temperatures) <= 1:
    v = 0
else:
    v = statistics.variance(temperatures)
    print(v)
# Out:
# 101.35984848484848

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stander_deviation=variance**0.5
print(stander_deviation)
# Out:
# 10.063139291854618

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
t=temperatures[::-1]
max_v=t[-1]
min_v=t[0]
range_v=max_v-min_v
print(range_v)
# Out:
# 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# IQR = Q3 - Q2
'''
if you have list of numbers = [1,2,3,4,5,6,7,8]
first -----> sort the list
second -----> make this list to 2 half
third ------> every half take median for the first half is Q1 and Second half if Q3
fourth -----> calculate IQR = Q3 - Q2
'''
n=len(temperatures)
temperatures.sort()
if n % 2 == 0:
    median1 = temperatures[n//2]
    median2 = temperatures[n//2 - 1]
    median = (median1 + median2)/2
    print(median)
else:
    median = temperatures[n//2]
    print(median)
# Out:
# 21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://teflpedia.com/Fisher%E2%80%93Pearson_sample_skewness?utm_source=chatgpt.com

# %%
# Step 2
D=[]
for x in range(len(temperatures)):
    D.append(temperatures[x]-mean)
print(D)
# Out:
# [-26.87878787878788, -21.87878787878788, -4.878787878787879, -3.878787878787879, -3.878787878787879, -2.878787878787879, -2.878787878787879, -2.878787878787879, -1.878787878787879, -1.878787878787879, -1.878787878787879, -1.878787878787879, -1.878787878787879, -0.8787878787878789, -0.8787878787878789, -0.8787878787878789, -0.8787878787878789, 0.1212121212121211, 0.1212121212121211, 0.1212121212121211, 0.1212121212121211, 1.121212121212121, 1.121212121212121, 1.121212121212121, 1.121212121212121, 2.121212121212121, 2.121212121212121, 2.121212121212121, 3.121212121212121, 3.121212121212121, 4.121212121212121, 28.12121212121212, 33.121212121212125]

# %%
SD=[]
for d in range(len(D)):
  SD.append(D[d]/stander_deviation)
print(SD)
# Out:
# [-2.671014193408245, -2.174151350215054, -0.4848176833582045, -0.38544511471956633, -0.38544511471956633, -0.28607254608092814, -0.28607254608092814, -0.28607254608092814, -0.18669997744228994, -0.18669997744228994, -0.18669997744228994, -0.18669997744228994, -0.18669997744228994, -0.08732740880365175, -0.08732740880365175, -0.08732740880365175, -0.08732740880365175, 0.012045159834986437, 0.012045159834986437, 0.012045159834986437, 0.012045159834986437, 0.11141772847362463, 0.11141772847362463, 0.11141772847362463, 0.11141772847362463, 0.21079029711226283, 0.21079029711226283, 0.21079029711226283, 0.310162865750901, 0.310162865750901, 0.4095354343895392, 2.794477081716856, 3.291339924910047]

# %%
# Step 4
cupe_SD=[]
for sd in range(len(SD)):
  cupe_SD.append(SD[sd]**3)
print(cupe_SD)
# Out:
# [-19.055861490199337, -10.277070142069201, -0.1139555170610066, -0.05726478531292863, -0.05726478531292863, -0.02341146245368585, -0.02341146245368585, -0.02341146245368585, -0.006507779004125431, -0.006507779004125431, -0.006507779004125431, -0.006507779004125431, -0.006507779004125431, -0.0006659654850945552, -0.0006659654850945552, -0.0006659654850945552, -0.0006659654850945552, 1.7475825595986475e-06, 1.7475825595986475e-06, 1.7475825595986475e-06, 1.7475825595986475e-06, 0.0013831296779898516, 0.0013831296779898516, 0.0013831296779898516, 0.0013831296779898516, 0.009365950280349025, 0.009365950280349025, 0.009365950280349025, 0.029837978868789937, 0.029837978868789937, 0.06868698492246542, 21.822357015578383, 35.65481716664802]

# %%
# Step 5
sum_cupe_SD=sum(cupe_SD)
print(sum_cupe_SD)
# Out:
# 27.972320620492226

# %%
skewness = (n / ((n - 1) * (n - 2))) * sum_cupe_SD
print(skewness)
# Out:
# 0.9305308270929873

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.itl.nist.gov/div898/handbook/eda/section3/eda35b.htm?utm_source=chatgpt.com
#
# Chat GPT

# %%
n = len(temperatures)

# %%
std_dev = standard_deviation

# %%
fourth_power = []
for sd in SD:
    fourth_power.append(sd ** 4)
sum_fourth = sum(fourth_power)

# %%
kurtosis = (n * (n + 1) * sum_fourth) / ((n - 1) * (n - 2) * (n - 3)) \
           - (3 * (n - 1)**2) / ((n - 2) * (n - 3))

# %%
print(kurtosis)
# Out:
# 6.188364591470457
